# %%
pwd
# Out:
# '/blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water'

# %%
#!/usr/bin/env python3
"""
Journal-quality stacked ACS-like plot with shared x-axis:

(a) Top panel:
    Polymer reaction rate normalized using:
      - reaction data from Polymer/<PE_SYSTEM>/Replica*/log.lammps
      - volume from Water/<WATER_SYSTEM>/Replica*/Reacter_with_Na/out

(b) Bottom panel:
    Water reaction rate normalized using:
      - reaction + volume data from Water/<WATER_SYSTEM>/Replica*/Reacter_with_Na/out

Outputs:
  PE_rate_compare_stacked_ACS_panels.png
  PE_rate_compare_stacked_ACS_panels.pdf
  water_system_volume_reaction_summary.csv

Mapping:
  PE_A1 -> Cocn_same_as_in_A1
  PE_A2 -> Cocn_same_as_in_A2
  PE_P1 -> Cocn_same_as_in_P1
  PE_P2 -> Cocn_same_as_in_P2
"""

from glob import glob
import os
import re
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# =========================================================
# SETTINGS
# =========================================================
POLYMER_BASE = "/blue/jsampath/avemula/Paper1_PE/Polymer"
WATER_BASE   = "/blue/jsampath/avemula/Paper1_PE/Water"

SYSTEM_MAP = {
    "PE_A1": "Cocn_same_as_in_A1",
    "PE_A2": "Cocn_same_as_in_A2",
    "PE_P1": "Cocn_same_as_in_P1",
    "PE_P2": "Cocn_same_as_in_P2",
}

POLYMER_SYSTEMS = list(SYSTEM_MAP.keys())
WATER_SYSTEMS   = list(SYSTEM_MAP.values())

DT_FS = 1.0
ROLL_POINTS = 25
NA = 6.02214076e23
ANG3_TO_L = 1e-27
BAND_ALPHA = 0.22
XMAX_NS = None

OUT_PREFIX = "PE_rate_compare_stacked_ACS_panels"
SUMMARY_CSV = "water_system_volume_reaction_summary.csv"

STEP_COL = "Step"
RXN_COL  = "f_myrxns[1]"
Y_LABEL_SIZE = 48   # choose any size you want
# =========================================================
# ACS-LIKE STYLE
# =========================================================
mpl.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica", "Arial", "DejaVu Sans"],
    "mathtext.fontset": "dejavusans",
    "mathtext.default": "regular",

    "font.size": 22,
    "axes.labelsize": 34,
    "axes.labelweight": "bold",
    "axes.linewidth": 5.0,

    "xtick.labelsize": 34,
    "ytick.labelsize": 34,
    "xtick.major.size": 12,
    "ytick.major.size": 12,
    "xtick.major.width": 5.0,
    "ytick.major.width": 5.0,
    "xtick.minor.width": 3.0,
    "ytick.minor.width": 3.0,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": False,
    "ytick.right": False,

    "legend.frameon": False,
    "lines.linewidth": 5.0,
})

# =========================================================
# HELPERS
# =========================================================
def extract_replica_number(path):
    m = re.search(r"/Replica(\d+)/", path)
    if m:
        return int(m.group(1))
    raise ValueError(f"Could not extract replica number from path: {path}")

def _find_col_case_insensitive(df, targets):
    cols_lower = {c.lower(): c for c in df.columns}
    for t in targets:
        if t.lower() in cols_lower:
            return cols_lower[t.lower()]
    return None

# =========================================================
# READ THERMO TABLE
# =========================================================
def read_thermo_table(filepath):
    with open(filepath, "r", errors="ignore") as f:
        lines = f.readlines()

    header = None
    header_idx = None

    for i, line in enumerate(lines):
        cols = line.split()
        if STEP_COL in cols and RXN_COL in cols:
            header = cols
            header_idx = i
            break

    if header is None:
        raise ValueError(f"Could not find thermo header with {STEP_COL} and {RXN_COL} in {filepath}")

    rows = []
    for line in lines[header_idx + 1:]:
        parts = line.split()
        if len(parts) != len(header):
            continue
        try:
            float(parts[header.index(STEP_COL)])
        except Exception:
            continue
        rows.append(parts)

    df = pd.DataFrame(rows, columns=header)

    for c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="ignore")

    df[STEP_COL] = pd.to_numeric(df[STEP_COL], errors="coerce")
    df[RXN_COL]  = pd.to_numeric(df[RXN_COL], errors="coerce")
    df = df.dropna(subset=[STEP_COL, RXN_COL]).sort_values(STEP_COL).reset_index(drop=True)

    return df

# =========================================================
# READ SINGLE MEAN VOLUME (L) FROM WATER OUT
# Used for top panel: polymer reaction + water volume
# =========================================================
def read_mean_volume_from_water_out(filepath):
    with open(filepath, "r", errors="ignore") as f:
        lines = f.readlines()

    # 1) Try thermo table with Vol / Volume / Lx Ly Lz
    for i, line in enumerate(lines):
        cols = line.split()
        cols_lower = [c.lower() for c in cols]

        has_step = "step" in cols_lower
        has_vol = ("vol" in cols_lower) or ("volume" in cols_lower)
        has_box = ("lx" in cols_lower and "ly" in cols_lower and "lz" in cols_lower)

        if has_step and (has_vol or has_box):
            header = cols
            rows = []

            for line2 in lines[i + 1:]:
                parts = line2.split()
                if len(parts) != len(header):
                    continue
                try:
                    step_col = next(j for j, c in enumerate(header) if c.lower() == "step")
                    float(parts[step_col])
                except Exception:
                    continue
                rows.append(parts)

            if rows:
                df = pd.DataFrame(rows, columns=header)
                for c in df.columns:
                    df[c] = pd.to_numeric(df[c], errors="coerce")

                vol_col = _find_col_case_insensitive(df, ["Vol", "Volume"])
                if vol_col is not None:
                    vol_ang3 = df[vol_col].to_numpy(dtype=float)
                    vol_ang3 = vol_ang3[np.isfinite(vol_ang3)]
                    if len(vol_ang3) > 0:
                        return float(np.mean(vol_ang3) * ANG3_TO_L)

                lx_col = _find_col_case_insensitive(df, ["Lx"])
                ly_col = _find_col_case_insensitive(df, ["Ly"])
                lz_col = _find_col_case_insensitive(df, ["Lz"])
                if lx_col is not None and ly_col is not None and lz_col is not None:
                    lx = df[lx_col].to_numpy(dtype=float)
                    ly = df[ly_col].to_numpy(dtype=float)
                    lz = df[lz_col].to_numpy(dtype=float)
                    vol_ang3 = lx * ly * lz
                    vol_ang3 = vol_ang3[np.isfinite(vol_ang3)]
                    if len(vol_ang3) > 0:
                        return float(np.mean(vol_ang3) * ANG3_TO_L)

    # 2) Try orthogonal box lines
    box_re = re.compile(
        r"orthogonal box\s*=\s*\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)\s+to\s+\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)"
    )

    vols_ang3 = []
    for line in lines:
        m = box_re.search(line)
        if m:
            xlo, ylo, zlo, xhi, yhi, zhi = map(float, m.groups())
            lx = xhi - xlo
            ly = yhi - ylo
            lz = zhi - zlo
            vols_ang3.append(lx * ly * lz)

    if len(vols_ang3) > 0:
        return float(np.mean(vols_ang3) * ANG3_TO_L)

    raise ValueError(f"Could not determine volume from {filepath}")

# =========================================================
# GET PER-ROW VOLUME ARRAY (L) FROM LOG
# Used for bottom panel: water reaction + water volume
# =========================================================
def volume_liters_array_from_log(filepath, df):
    # 1) direct volume column
    vol_col = _find_col_case_insensitive(df, ["Vol", "Volume"])
    if vol_col is not None:
        vol_ang3 = pd.to_numeric(df[vol_col], errors="coerce").values
        if np.isfinite(vol_ang3).any():
            return vol_ang3 * ANG3_TO_L

    # 2) compute from box lengths
    lx_col = _find_col_case_insensitive(df, ["Lx", "LX"])
    ly_col = _find_col_case_insensitive(df, ["Ly", "LY"])
    lz_col = _find_col_case_insensitive(df, ["Lz", "LZ"])
    if lx_col is not None and ly_col is not None and lz_col is not None:
        lx = pd.to_numeric(df[lx_col], errors="coerce").values
        ly = pd.to_numeric(df[ly_col], errors="coerce").values
        lz = pd.to_numeric(df[lz_col], errors="coerce").values
        vol_ang3 = lx * ly * lz
        if np.isfinite(vol_ang3).any():
            return vol_ang3 * ANG3_TO_L

    # 3) parse orthogonal box from raw log text
    with open(filepath, "r", errors="ignore") as f:
        text = f.read().splitlines()

    box_re = re.compile(
        r"orthogonal box\s*=\s*\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)\s+to\s+\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)"
    )

    last_box = None
    for line in text:
        m = box_re.search(line)
        if m:
            xlo, ylo, zlo, xhi, yhi, zhi = map(float, m.groups())
            lx = xhi - xlo
            ly = yhi - ylo
            lz = zhi - zlo
            last_box = (lx, ly, lz)

    if last_box is not None:
        lx, ly, lz = last_box
        vol_ang3 = lx * ly * lz
        return np.full(len(df), vol_ang3 * ANG3_TO_L, dtype=float)

    raise ValueError(
        f"Could not determine volume for {filepath}. "
        f"Add Vol (or Lx Ly Lz) to thermo_style, or ensure the log contains an 'orthogonal box =' line."
    )

# =========================================================
# COMPUTE TOP PANEL RATE
# polymer rxn / (NA * mean water volume)
# =========================================================
def compute_top_rate(df_rxn, volume_L):
    step = df_rxn[STEP_COL].values.astype(float)
    rxn  = df_rxn[RXN_COL].values.astype(float)

    time_ns = step * DT_FS * 1e-6
    dr = np.diff(rxn)
    dt = np.diff(time_ns)

    rate = np.full_like(rxn, np.nan, dtype=float)
    valid = dt != 0
    rate[1:] = np.nan
    rate[1:][valid] = dr[valid] / dt[valid]   # reactions / ns

    out = pd.DataFrame({
        "time_ns": time_ns,
        "rate": rate
    })

    if ROLL_POINTS and ROLL_POINTS > 1:
        out["rate_roll"] = out["rate"].rolling(
            ROLL_POINTS, center=True, min_periods=2
        ).mean()
    else:
        out["rate_roll"] = out["rate"]

    out["y"] = out["rate_roll"] / (NA * volume_L)
    return out

# =========================================================
# COMPUTE BOTTOM PANEL RATE
# water rxn / (NA * instantaneous water volume)
# =========================================================
def compute_bottom_rate(df, V_L):
    step = df[STEP_COL].values.astype(float)
    rxn  = df[RXN_COL].values.astype(float)

    time_ns = step * DT_FS * 1e-6
    dr = np.diff(rxn)
    dt = np.diff(time_ns)

    rate = np.full_like(rxn, np.nan, dtype=float)
    valid = dt != 0
    rate[1:] = np.nan
    rate[1:][valid] = dr[valid] / dt[valid]   # reactions / ns

    out = pd.DataFrame({
        "time_ns": time_ns,
        "rate": rate
    })

    if ROLL_POINTS and ROLL_POINTS > 1:
        out["rate_roll"] = out["rate"].rolling(
            ROLL_POINTS, center=True, min_periods=2
        ).mean()
    else:
        out["rate_roll"] = out["rate"]

    V_L = np.asarray(V_L, dtype=float)
    if V_L.shape[0] != out.shape[0]:
        raise ValueError("V_L length does not match thermo rows length.")

    out["y"] = out["rate_roll"] / (NA * V_L)
    return out

# =========================================================
# BUILD MATCHED FILES FOR TOP PANEL
# =========================================================
print("\n" + "=" * 100)
print("BUILDING MATCHED POLYMER/WATER REPLICA FILES FOR TOP PANEL")
print("=" * 100)

TOP_SYSTEM_FILES = {}

for poly_system, water_system in SYSTEM_MAP.items():
    poly_logs = sorted(glob(f"{POLYMER_BASE}/{poly_system}/Replica*/log.lammps"))
    water_outs = sorted(glob(f"{WATER_BASE}/{water_system}/Replica*/Reacter_with_Na/out"))

    print(f"\n{poly_system}")
    print(f"  Polymer logs found : {len(poly_logs)}")
    print(f"  Water out files    : {len(water_outs)}")

    poly_map = {extract_replica_number(p): p for p in poly_logs}
    water_map = {extract_replica_number(w): w for w in water_outs}
    common_reps = sorted(set(poly_map) & set(water_map))

    matched = []
    for rep in common_reps:
        matched.append({
            "replica": rep,
            "poly_log": poly_map[rep],
            "water_out": water_map[rep],
        })
        print(f"  Matched Replica{rep}")

    if len(matched) == 0:
        print(f"  WARNING: No matched replicas for {poly_system}")

    TOP_SYSTEM_FILES[poly_system] = matched

# =========================================================
# PROCESS TOP PANEL DATA
# =========================================================
print("\n" + "=" * 100)
print("PROCESSING TOP PANEL: POLYMER REACTION + WATER VOLUME")
print("=" * 100)

top_system_stats = {}

for poly_system in POLYMER_SYSTEMS:
    matched_files = TOP_SYSTEM_FILES.get(poly_system, [])
    reps = []

    for item in matched_files:
        rep = item["replica"]
        poly_log = item["poly_log"]
        water_out = item["water_out"]

        try:
            df_rxn = read_thermo_table(poly_log)
            volume_L = read_mean_volume_from_water_out(water_out)
            rep_df = compute_top_rate(df_rxn, volume_L)
            reps.append(rep_df)

            print(f"{poly_system} Replica{rep}: mean water volume = {volume_L:.6e} L")

        except Exception as e:
            print(f"WARNING: Skipping {poly_system} Replica{rep}: {e}")

    if len(reps) == 0:
        continue

    grid = reps[0]["time_ns"].values
    Y = []

    for r in reps:
        y = np.interp(grid, r["time_ns"].values, r["y"].values)
        Y.append(y)

    Y = np.asarray(Y, dtype=float)

    mean = np.nanmean(Y, axis=0)
    std  = np.nanstd(Y, axis=0, ddof=1) if Y.shape[0] > 1 else np.zeros_like(mean)

    top_system_stats[poly_system] = pd.DataFrame({
        "time_ns": grid,
        "mean": mean,
        "std": std
    })

# =========================================================
# BUILD WATER SYSTEM FILES FOR BOTTOM PANEL
# =========================================================
print("\n" + "=" * 100)
print("BUILDING WATER FILES FOR BOTTOM PANEL")
print("=" * 100)

BOTTOM_SYSTEM_FILES = {}
for water_system in WATER_SYSTEMS:
    files = sorted(glob(f"{WATER_BASE}/{water_system}/Replica*/Reacter_with_Na/out"))
    BOTTOM_SYSTEM_FILES[water_system] = files
    print(f"{water_system}: {len(files)} replicas found")
    if len(files) == 0:
        print(f"  WARNING: No replicas found for {water_system}")

# =========================================================
# PROCESS BOTTOM PANEL DATA
# =========================================================
print("\n" + "=" * 100)
print("PROCESSING BOTTOM PANEL: WATER REACTION + WATER VOLUME")
print("=" * 100)

bottom_system_stats = {}
volume_summary = {}
reaction_summary = {}

for system, files in BOTTOM_SYSTEM_FILES.items():
    reps = []
    replica_volumes_ang3 = []
    replica_reactions = []

    print("\n" + "-" * 90)
    print(f"SYSTEM: {system}")
    print("-" * 90)

    for fpath in files:
        try:
            df = read_thermo_table(fpath)
            V_L = volume_liters_array_from_log(fpath, df)
            rep = compute_bottom_rate(df, V_L)
            reps.append(rep)

            final_rxn = float(df[RXN_COL].iloc[-1])
            replica_reactions.append(final_rxn)

            V_ang3 = V_L / ANG3_TO_L
            v0_ang3    = np.nanmean(V_ang3[:1])
            vlast_ang3 = np.nanmean(V_ang3[-1:])
            vmean_ang3 = np.nanmean(V_ang3)

            v0_L    = v0_ang3 * ANG3_TO_L
            vlast_L = vlast_ang3 * ANG3_TO_L
            vmean_L = vmean_ang3 * ANG3_TO_L

            replica_name = os.path.basename(os.path.dirname(os.path.dirname(fpath)))

            print(f"{replica_name}")
            print(f"  log file        : {fpath}")
            print(f"  Initial volume  : {v0_ang3:.6f} Å^3   ({v0_L:.6e} L)")
            print(f"  Final volume    : {vlast_ang3:.6f} Å^3   ({vlast_L:.6e} L)")
            print(f"  Mean volume     : {vmean_ang3:.6f} Å^3   ({vmean_L:.6e} L)")
            print(f"  Final reactions : {final_rxn:.6f}")

            replica_volumes_ang3.append(vmean_ang3)

        except Exception as e:
            print(f"WARNING: Skipping {fpath}: {e}")

    if len(reps) == 0:
        continue

    replica_volumes_ang3 = np.asarray(replica_volumes_ang3, dtype=float)
    volume_summary[system] = {
        "mean_ang3": np.nanmean(replica_volumes_ang3),
        "std_ang3": np.nanstd(replica_volumes_ang3, ddof=1) if len(replica_volumes_ang3) > 1 else 0.0,
        "mean_L": np.nanmean(replica_volumes_ang3) * ANG3_TO_L,
        "std_L": (np.nanstd(replica_volumes_ang3, ddof=1) if len(replica_volumes_ang3) > 1 else 0.0) * ANG3_TO_L,
    }

    replica_reactions = np.asarray(replica_reactions, dtype=float)
    reaction_summary[system] = {
        "mean_rxn": np.nanmean(replica_reactions),
        "std_rxn": np.nanstd(replica_reactions, ddof=1) if len(replica_reactions) > 1 else 0.0,
    }

    grid = reps[0]["time_ns"].values
    Y = []

    for r in reps:
        y = np.interp(grid, r["time_ns"].values, r["y"].values)
        Y.append(y)

    Y = np.asarray(Y, dtype=float)

    mean = np.nanmean(Y, axis=0)
    std  = np.nanstd(Y, axis=0, ddof=1) if Y.shape[0] > 1 else np.zeros_like(mean)

    bottom_system_stats[system] = pd.DataFrame({
        "time_ns": grid,
        "mean": mean,
        "std": std
    })

# =========================================================
# PRINT FINAL WATER SYSTEM SUMMARIES
# =========================================================
print("\n" + "#" * 90)
print("FINAL WATER SYSTEM-WISE BOX VOLUME SUMMARY")
print("#" * 90)
for system in WATER_SYSTEMS:
    if system not in volume_summary:
        continue
    vs = volume_summary[system]
    print(f"{system}")
    print(f"  Mean box volume across replicas = {vs['mean_ang3']:.6f} ± {vs['std_ang3']:.6f} Å^3")
    print(f"                                 = {vs['mean_L']:.6e} ± {vs['std_L']:.6e} L")

print("\n" + "#" * 90)
print("FINAL WATER SYSTEM-WISE REACTION SUMMARY")
print("#" * 90)
for system in WATER_SYSTEMS:
    if system not in reaction_summary:
        continue
    rs = reaction_summary[system]
    print(f"{system}")
    print(f"  Mean final reactions across replicas = {rs['mean_rxn']:.6f} ± {rs['std_rxn']:.6f}")

# =========================================================
# SAVE WATER SUMMARY CSV
# =========================================================
rows = []
for system in WATER_SYSTEMS:
    if system not in volume_summary:
        continue

    vol = volume_summary[system]
    rxn = reaction_summary.get(system, {"mean_rxn": np.nan, "std_rxn": np.nan})

    rows.append({
        "system": system,
        "mean_volume_ang3": vol["mean_ang3"],
        "std_volume_ang3": vol["std_ang3"],
        "mean_volume_L": vol["mean_L"],
        "std_volume_L": vol["std_L"],
        "mean_reactions": rxn["mean_rxn"],
        "std_reactions": rxn["std_rxn"],
    })

summary_df = pd.DataFrame(rows)
summary_df.to_csv(SUMMARY_CSV, index=False)

print(f"\nSaved: {SUMMARY_CSV}")
print(summary_df)

# =========================================================
# PLOT STACKED PANELS
# =========================================================
# =========================================================
# PLOT STACKED PANELS
# =========================================================
fig, (ax1, ax2) = plt.subplots(
    2, 1,
    figsize=(10, 20),
    sharex=True,
    gridspec_kw={"hspace": 0.08}
)

ax1.set_box_aspect(1)
ax2.set_box_aspect(1)

style_top = {
    "PE_A1": dict(color="black"),
    "PE_A2": dict(color="blue"),
    "PE_P1": dict(color="red"),
    "PE_P2": dict(color="green"),
}

style_bottom = {
    "Cocn_same_as_in_A1": dict(color="black"),
    "Cocn_same_as_in_A2": dict(color="blue"),
    "Cocn_same_as_in_P1": dict(color="red"),
    "Cocn_same_as_in_P2": dict(color="green"),
}

legend_labels = {
    "Cocn_same_as_in_A1": "0.257 M",
    "Cocn_same_as_in_A2": "0.128 M",
    "Cocn_same_as_in_P1": "0.578 M",
    "Cocn_same_as_in_P2": "0.210 M",
}

# -------------------------
# TOP PANEL (a)
# -------------------------
for system in POLYMER_SYSTEMS:

    if system not in top_system_stats:
        continue

    color = style_top.get(system, {}).get("color", "black")
    df = top_system_stats[system]

    x = df["time_ns"].values
    y = df["mean"].values
    e = df["std"].values

    ax1.plot(x, y, color=color)
    ax1.fill_between(x, y - e, y + e, color=color, alpha=BAND_ALPHA)

ax1.set_ylabel(
    r"$\mathbf{\frac{\#\ reactions}{N_A \cdot V \cdot \Delta t}}$",
    fontsize=Y_LABEL_SIZE,
    labelpad=25
)

ax1.text(
    0.03, 0.92, "(a)",
    transform=ax1.transAxes,
    fontsize=36,
    fontweight="bold"
)

# ---- custom ticks ----
ax1.set_yticks([0,1000,2000,3000,4000,5000])
ax1.minorticks_off()

# remove x ticks because shared axis
ax1.tick_params(labelbottom=False)


# -------------------------
# BOTTOM PANEL (b) — SORTED + EXPLICIT LEGEND
# -------------------------
sorted_systems = []

for system in WATER_SYSTEMS:
    if system in bottom_system_stats:
        label = legend_labels.get(system, system)
        val = float(label.split()[0])   # e.g. "0.128 M" -> 0.128
        sorted_systems.append((val, system))

sorted_systems.sort(key=lambda x: x[0])

handles = []
labels = []

for _, system in sorted_systems:
    color = style_bottom.get(system, {}).get("color", "black")
    df = bottom_system_stats[system]

    x = df["time_ns"].values
    y = df["mean"].values
    e = df["std"].values
    lbl = legend_labels.get(system, system)

    line, = ax2.plot(
        x, y,
        color=color,
        label=lbl
    )

    ax2.fill_between(x, y - e, y + e, color=color, alpha=BAND_ALPHA)

    handles.append(line)
    labels.append(lbl)

ax2.set_xlabel("Time [ns]", fontsize=36, fontweight="bold")

ax2.set_ylabel(
    r"$\mathbf{\frac{\#\ reactions}{N_A \cdot V \cdot \Delta t}}$",
    fontsize=Y_LABEL_SIZE,
    labelpad=25
)

ax2.text(
    0.03, 0.92, "(b)",
    transform=ax2.transAxes,
    fontsize=36,
    fontweight="bold"
)

ax2.set_yticks([200, 400, 600])

# -------------------------
# LEGEND ONLY IN PANEL (b)
# -------------------------
leg = ax2.legend(
    handles,
    labels,
    loc="upper right",
    fontsize=28,
    frameon=False,
    handlelength=2.5
)

for text in leg.get_texts():
    text.set_fontweight("bold")
# -------------------------
# LEGEND ONLY IN PANEL (b)
# -------------------------
leg = ax2.legend(
    loc="upper right",
    fontsize=28,
    frameon=False,
    handlelength=2.5
)

for text in leg.get_texts():
    text.set_fontweight("bold")


# -------------------------
# STYLE
# -------------------------
for ax in [ax1, ax2]:

    for spine in ax.spines.values():
        spine.set_linewidth(5)

    ax.tick_params(
        direction="in",
        width=5,
        length=12
    )

    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight("bold")
        label.set_fontsize(34)


fig.tight_layout()

fig.savefig(f"{OUT_PREFIX}.png", dpi=600, bbox_inches="tight")
fig.savefig(f"{OUT_PREFIX}.pdf", bbox_inches="tight")

plt.show()

print("Saved:", f"{OUT_PREFIX}.png")
print("Saved:", f"{OUT_PREFIX}.pdf")
# Out:
# ====================================================================================================
# BUILDING MATCHED POLYMER/WATER REPLICA FILES FOR TOP PANEL
# ====================================================================================================
#
# PE_A1
#   Polymer logs found : 4
#   Water out files    : 3
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# PE_A2
#   Polymer logs found : 4
#   Water out files    : 3
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# PE_P1
#   Polymer logs found : 4
#   Water out files    : 3
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# PE_P2
#   Polymer logs found : 4
#   Water out files    : 3
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# ====================================================================================================
# PROCESSING TOP PANEL: POLYMER REACTION + WATER VOLUME
# ====================================================================================================
# PE_A1 Replica1: mean water volume = 1.198563e-22 L
# PE_A1 Replica2: mean water volume = 1.198563e-22 L
# PE_A1 Replica3: mean water volume = 1.198563e-22 L
# PE_A2 Replica1: mean water volume = 2.393367e-22 L
# PE_A2 Replica2: mean water volume = 2.393367e-22 L
# PE_A2 Replica3: mean water volume = 2.393367e-22 L
# PE_P1 Replica1: mean water volume = 5.403150e-23 L
# PE_P1 Replica2: mean water volume = 5.403150e-23 L
# PE_P1 Replica3: mean water volume = 5.403150e-23 L
# PE_P2 Replica1: mean water volume = 1.473245e-22 L
# PE_P2 Replica2: mean water volume = 1.473245e-22 L
# PE_P2 Replica3: mean water volume = 1.473245e-22 L
#
# ====================================================================================================
# BUILDING WATER FILES FOR BOTTOM PANEL
# ====================================================================================================
# Cocn_same_as_in_A1: 3 replicas found
# Cocn_same_as_in_A2: 3 replicas found
# Cocn_same_as_in_P1: 3 replicas found
# Cocn_same_as_in_P2: 3 replicas found
#
# ====================================================================================================
# PROCESSING BOTTOM PANEL: WATER REACTION + WATER VOLUME
# ====================================================================================================
#
# ------------------------------------------------------------------------------------------
# SYSTEM: Cocn_same_as_in_A1
# ------------------------------------------------------------------------------------------
# Replica1
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_A1/Replica1/Reacter_with_Na/out
#   Initial volume  : 119856.326770 Å^3   (1.198563e-22 L)
#   Final volume    : 119856.326770 Å^3   (1.198563e-22 L)
#   Mean volume     : 119856.326770 Å^3   (1.198563e-22 L)
#   Final reactions : 12004.000000
# Replica2
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_A1/Replica2/Reacter_with_Na/out
#   Initial volume  : 119856.326770 Å^3   (1.198563e-22 L)
#   Final volume    : 119856.326770 Å^3   (1.198563e-22 L)
#   Mean volume     : 119856.326770 Å^3   (1.198563e-22 L)
#   Final reactions : 11816.000000
# Replica3
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_A1/Replica3/Reacter_with_Na/out
#   Initial volume  : 119856.326770 Å^3   (1.198563e-22 L)
#   Final volume    : 119856.326770 Å^3   (1.198563e-22 L)
#   Mean volume     : 119856.326770 Å^3   (1.198563e-22 L)
#   Final reactions : 11923.000000
#
# ------------------------------------------------------------------------------------------
# SYSTEM: Cocn_same_as_in_A2
# ------------------------------------------------------------------------------------------
# Replica1
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_A2/Replica1/Reacter_with_Na/out
#   Initial volume  : 239336.676446 Å^3   (2.393367e-22 L)
#   Final volume    : 239336.676446 Å^3   (2.393367e-22 L)
#   Mean volume     : 239336.676446 Å^3   (2.393367e-22 L)
#   Final reactions : 25372.000000
# Replica2
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_A2/Replica2/Reacter_with_Na/out
#   Initial volume  : 239336.676446 Å^3   (2.393367e-22 L)
#   Final volume    : 239336.676446 Å^3   (2.393367e-22 L)
#   Mean volume     : 239336.676446 Å^3   (2.393367e-22 L)
#   Final reactions : 25242.000000
# Replica3
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_A2/Replica3/Reacter_with_Na/out
#   Initial volume  : 239336.676446 Å^3   (2.393367e-22 L)
#   Final volume    : 239336.676446 Å^3   (2.393367e-22 L)
#   Mean volume     : 239336.676446 Å^3   (2.393367e-22 L)
#   Final reactions : 25023.000000
#
# ------------------------------------------------------------------------------------------
# SYSTEM: Cocn_same_as_in_P1
# ------------------------------------------------------------------------------------------
# Replica1
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_P1/Replica1/Reacter_with_Na/out
#   Initial volume  : 54031.499967 Å^3   (5.403150e-23 L)
#   Final volume    : 54031.499967 Å^3   (5.403150e-23 L)
#   Mean volume     : 54031.499967 Å^3   (5.403150e-23 L)
#   Final reactions : 8898.000000
# Replica2
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_P1/Replica2/Reacter_with_Na/out
#   Initial volume  : 54031.499967 Å^3   (5.403150e-23 L)
#   Final volume    : 54031.499967 Å^3   (5.403150e-23 L)
#   Mean volume     : 54031.499967 Å^3   (5.403150e-23 L)
#   Final reactions : 8676.000000
# Replica3
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_P1/Replica3/Reacter_with_Na/out
#   Initial volume  : 54031.499967 Å^3   (5.403150e-23 L)
#   Final volume    : 54031.499967 Å^3   (5.403150e-23 L)
#   Mean volume     : 54031.499967 Å^3   (5.403150e-23 L)
#   Final reactions : 8976.000000
#
# ------------------------------------------------------------------------------------------
# SYSTEM: Cocn_same_as_in_P2
# ------------------------------------------------------------------------------------------
# Replica1
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_P2/Replica1/Reacter_with_Na/out
#   Initial volume  : 147324.515769 Å^3   (1.473245e-22 L)
#   Final volume    : 147324.515769 Å^3   (1.473245e-22 L)
#   Mean volume     : 147324.515769 Å^3   (1.473245e-22 L)
#   Final reactions : 20897.000000
# Replica2
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_P2/Replica2/Reacter_with_Na/out
#   Initial volume  : 147324.515769 Å^3   (1.473245e-22 L)
#   Final volume    : 147324.515769 Å^3   (1.473245e-22 L)
#   Mean volume     : 147324.515769 Å^3   (1.473245e-22 L)
#   Final reactions : 21207.000000
# Replica3
#   log file        : /blue/jsampath/avemula/Paper1_PE/Water/Cocn_same_as_in_P2/Replica3/Reacter_with_Na/out
#   Initial volume  : 147324.515769 Å^3   (1.473245e-22 L)
#   Final volume    : 147324.515769 Å^3   (1.473245e-22 L)
#   Mean volume     : 147324.515769 Å^3   (1.473245e-22 L)
#   Final reactions : 21340.000000
#
# ##########################################################################################
# FINAL WATER SYSTEM-WISE BOX VOLUME SUMMARY
# ##########################################################################################
# Cocn_same_as_in_A1
#   Mean box volume across replicas = 119856.326770 ± 0.000000 Å^3
#                                  = 1.198563e-22 ± 0.000000e+00 L
# Cocn_same_as_in_A2
#   Mean box volume across replicas = 239336.676446 ± 0.000000 Å^3
#                                  = 2.393367e-22 ± 0.000000e+00 L
# Cocn_same_as_in_P1
#   Mean box volume across replicas = 54031.499967 ± 0.000000 Å^3
#                                  = 5.403150e-23 ± 8.911192e-39 L
# Cocn_same_as_in_P2
#   Mean box volume across replicas = 147324.515769 ± 0.000000 Å^3
#                                  = 1.473245e-22 ± 0.000000e+00 L
#
# ##########################################################################################
# FINAL WATER SYSTEM-WISE REACTION SUMMARY
# ##########################################################################################
# Cocn_same_as_in_A1
#   Mean final reactions across replicas = 11914.333333 ± 94.299169
# Cocn_same_as_in_A2
#   Mean final reactions across replicas = 25212.333333 ± 176.381216
# Cocn_same_as_in_P1
#   Mean final reactions across replicas = 8850.000000 ± 155.653461
# Cocn_same_as_in_P2
#   Mean final reactions across replicas = 21148.000000 ± 227.316959
#
# Saved: water_system_volume_reaction_summary.csv
#                system  mean_volume_ang3  std_volume_ang3  mean_volume_L  \
# 0  Cocn_same_as_in_A1     119856.326770     0.000000e+00   1.198563e-22
# 1  Cocn_same_as_in_A2     239336.676446     0.000000e+00   2.393367e-22
# 2  Cocn_same_as_in_P1      54031.499967     8.911192e-12   5.403150e-23
# 3  Cocn_same_as_in_P2     147324.515769     0.000000e+00   1.473245e-22
#
#    std_volume_L  mean_reactions  std_reactions
# 0  0.000000e+00    11914.333333      94.299169
# 1  0.000000e+00    25212.333333     176.381216
# 2  8.911192e-39     8850.000000     155.653461
# 3  0.000000e+00    21148.000000     227.316959
# /scratch/local/28588013/ipykernel_2002999/4175955179.py:763: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Saved: PE_rate_compare_stacked_ACS_panels.png
# Saved: PE_rate_compare_stacked_ACS_panels.pdf

# %%
#!/usr/bin/env python3
"""
Journal-quality stacked ACS-like plot with shared x-axis:

(a) Top panel:
    Polymer reaction rate normalized using:
      - reaction data from Polymer/<PE_SYSTEM>/Replica*/log.lammps
      - volume from Water/TMA_OH_water/<CONCENTRATION>/Reacter_3.0/Replica*/log.lammps

(b) Bottom panel:
    Water reaction rate normalized using:
      - reaction + volume data from Water/TMA_OH_water/<CONCENTRATION>/Reacter_3.0/Replica*/log.lammps

Replica filter: exactly REQUIRED_REPLICAS replicas must be found for both
polymer and water sides — if not, the system is skipped with a warning.

Outputs:
  PE_rate_compare_stacked_ACS_panels.png
  PE_rate_compare_stacked_ACS_panels.pdf
  water_system_volume_reaction_summary.csv
"""

from glob import glob
import os
import re
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# =========================================================
# SETTINGS
# =========================================================
POLYMER_BASE      = "/blue/jsampath/avemula/Paper1_PE/Polymer"
WATER_BASE        = "/blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water"

REQUIRED_REPLICAS = 3      # enforce this many replicas for every system

# Map each polymer system to its matching water concentration folder
SYSTEM_MAP = {
    "PE_A1": "0.257M",
    "PE_A2": "0.128M",
    "PE_P1": "0.578M",
    "PE_P2": "0.210M",
}

# Display labels for the legend (concentration string -> label shown on plot)
DISPLAY_LABELS = {
    "0.128M": "0.128 M",
    "0.210M": "0.210 M",
    "0.257M": "0.257 M",
    "0.578M": "0.578 M",
}

POLYMER_SYSTEMS = list(SYSTEM_MAP.keys())
WATER_SYSTEMS   = list(SYSTEM_MAP.values())

DT_FS       = 1.0
ROLL_POINTS = 25
NA          = 6.02214076e23
ANG3_TO_L   = 1e-27
BAND_ALPHA  = 0.22
XMAX_NS     = None

OUT_PREFIX  = "PE_rate_compare_stacked_ACS_panels"
SUMMARY_CSV = "water_system_volume_reaction_summary.csv"

STEP_COL     = "Step"
RXN_COL      = "f_myrxns[1]"
Y_LABEL_SIZE = 48

# =========================================================
# COLORS — Wong colorblind-safe palette
# =========================================================
CONC_COLORS = {
    "0.128M": "#A8CBE8",   # black
    "0.210M": "#4A97C8",   # amber
    "0.257M": "#1A5FA0",   # sky blue
    "0.578M": "#08306B",   # teal
}

def poly_color(poly_system):
    return CONC_COLORS.get(SYSTEM_MAP.get(poly_system, ""), "gray")

# =========================================================
# ACS-LIKE RCPARAMS
# =========================================================
mpl.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica", "Arial", "DejaVu Sans"],
    "mathtext.fontset": "dejavusans",
    "mathtext.default": "regular",

    "font.size": 22,
    "axes.labelsize": 34,
    "axes.labelweight": "bold",
    "axes.linewidth": 5.0,

    "xtick.labelsize": 34,
    "ytick.labelsize": 34,
    "xtick.major.size": 12,
    "ytick.major.size": 12,
    "xtick.major.width": 5.0,
    "ytick.major.width": 5.0,
    "xtick.minor.width": 3.0,
    "ytick.minor.width": 3.0,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": False,
    "ytick.right": False,

    "legend.frameon": False,
    "lines.linewidth": 5.0,
})

# =========================================================
# REPLICA FILTER
# =========================================================
def filter_to_n_replicas(paths, n, label):
    if len(paths) < n:
        raise ValueError(
            f"[{label}] Only {len(paths)} replica(s) found but "
            f"{n} are required. Paths found:\n" +
            "\n".join(f"  {p}" for p in paths)
        )
    if len(paths) > n:
        kept    = paths[:n]
        dropped = paths[n:]
        print(
            f"  [{label}] {len(paths)} replicas found — "
            f"keeping first {n}, dropping:\n" +
            "\n".join(f"    {p}" for p in dropped)
        )
        return kept
    return paths   # exactly n

# =========================================================
# HELPERS
# =========================================================
def extract_replica_number(path):
    m = re.search(r"/Replica(\d+)/", path)
    if m:
        return int(m.group(1))
    raise ValueError(f"Could not extract replica number from: {path}")

def _find_col_case_insensitive(df, targets):
    cols_lower = {c.lower(): c for c in df.columns}
    for t in targets:
        if t.lower() in cols_lower:
            return cols_lower[t.lower()]
    return None

# =========================================================
# READ THERMO TABLE
# =========================================================
def read_thermo_table(filepath):
    with open(filepath, "r", errors="ignore") as f:
        lines = f.readlines()

    header = None
    header_idx = None
    for i, line in enumerate(lines):
        cols = line.split()
        if STEP_COL in cols and RXN_COL in cols:
            header = cols
            header_idx = i
            break

    if header is None:
        raise ValueError(
            f"Could not find thermo header with '{STEP_COL}' and "
            f"'{RXN_COL}' in:\n  {filepath}"
        )

    rows = []
    for line in lines[header_idx + 1:]:
        parts = line.split()
        if len(parts) != len(header):
            continue
        try:
            float(parts[header.index(STEP_COL)])
        except Exception:
            continue
        rows.append(parts)

    df = pd.DataFrame(rows, columns=header)
    for c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="ignore")
    df[STEP_COL] = pd.to_numeric(df[STEP_COL], errors="coerce")
    df[RXN_COL]  = pd.to_numeric(df[RXN_COL],  errors="coerce")
    df = (df.dropna(subset=[STEP_COL, RXN_COL])
            .sort_values(STEP_COL)
            .reset_index(drop=True))
    return df

# =========================================================
# VOLUME: SINGLE MEAN VALUE (used for top panel)
# =========================================================
def read_mean_volume_from_log(filepath):
    with open(filepath, "r", errors="ignore") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        cols       = line.split()
        cols_lower = [c.lower() for c in cols]
        has_step   = "step" in cols_lower
        has_vol    = "vol" in cols_lower or "volume" in cols_lower
        has_box    = ("lx" in cols_lower and "ly" in cols_lower
                      and "lz" in cols_lower)

        if has_step and (has_vol or has_box):
            header = cols
            rows   = []
            for line2 in lines[i + 1:]:
                parts = line2.split()
                if len(parts) != len(header):
                    continue
                try:
                    si = next(j for j, c in enumerate(header)
                              if c.lower() == "step")
                    float(parts[si])
                except Exception:
                    continue
                rows.append(parts)

            if rows:
                df = pd.DataFrame(rows, columns=header)
                for c in df.columns:
                    df[c] = pd.to_numeric(df[c], errors="coerce")

                vol_col = _find_col_case_insensitive(df, ["Vol", "Volume"])
                if vol_col is not None:
                    v = df[vol_col].to_numpy(dtype=float)
                    v = v[np.isfinite(v)]
                    if len(v) > 0:
                        return float(np.mean(v) * ANG3_TO_L)

                lx_c = _find_col_case_insensitive(df, ["Lx"])
                ly_c = _find_col_case_insensitive(df, ["Ly"])
                lz_c = _find_col_case_insensitive(df, ["Lz"])
                if all(c is not None for c in [lx_c, ly_c, lz_c]):
                    v = (df[lx_c].to_numpy(dtype=float) *
                         df[ly_c].to_numpy(dtype=float) *
                         df[lz_c].to_numpy(dtype=float))
                    v = v[np.isfinite(v)]
                    if len(v) > 0:
                        return float(np.mean(v) * ANG3_TO_L)

    box_re = re.compile(
        r"orthogonal box\s*=\s*\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)"
        r"\s+to\s+\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)"
    )
    vols = []
    for line in lines:
        m = box_re.search(line)
        if m:
            xlo, ylo, zlo, xhi, yhi, zhi = map(float, m.groups())
            vols.append((xhi - xlo) * (yhi - ylo) * (zhi - zlo))

    if vols:
        return float(np.mean(vols) * ANG3_TO_L)

    raise ValueError(f"Could not determine volume from:\n  {filepath}")

# =========================================================
# VOLUME: PER-ROW ARRAY (used for bottom panel)
# =========================================================
def volume_liters_array_from_log(filepath, df):
    vol_col = _find_col_case_insensitive(df, ["Vol", "Volume"])
    if vol_col is not None:
        v = pd.to_numeric(df[vol_col], errors="coerce").values
        if np.isfinite(v).any():
            return v * ANG3_TO_L

    lx_c = _find_col_case_insensitive(df, ["Lx", "LX"])
    ly_c = _find_col_case_insensitive(df, ["Ly", "LY"])
    lz_c = _find_col_case_insensitive(df, ["Lz", "LZ"])
    if all(c is not None for c in [lx_c, ly_c, lz_c]):
        lx = pd.to_numeric(df[lx_c], errors="coerce").values
        ly = pd.to_numeric(df[ly_c], errors="coerce").values
        lz = pd.to_numeric(df[lz_c], errors="coerce").values
        v  = lx * ly * lz
        if np.isfinite(v).any():
            return v * ANG3_TO_L

    box_re = re.compile(
        r"orthogonal box\s*=\s*\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)"
        r"\s+to\s+\(([-+0-9.eE]+)\s+([-+0-9.eE]+)\s+([-+0-9.eE]+)\)"
    )
    last_box = None
    with open(filepath, "r", errors="ignore") as f:
        for line in f:
            m = box_re.search(line)
            if m:
                xlo, ylo, zlo, xhi, yhi, zhi = map(float, m.groups())
                last_box = (xhi - xlo, yhi - ylo, zhi - zlo)

    if last_box is not None:
        lx, ly, lz = last_box
        return np.full(len(df), lx * ly * lz * ANG3_TO_L, dtype=float)

    raise ValueError(
        f"Could not determine volume for:\n  {filepath}\n"
        "Add Vol (or Lx Ly Lz) to thermo_style, or ensure the log "
        "contains an 'orthogonal box =' line."
    )

# =========================================================
# RATE COMPUTATION
# =========================================================
def _rolling_rate(df, time_ns):
    rxn   = df[RXN_COL].values.astype(float)
    dr    = np.diff(rxn)
    dt    = np.diff(time_ns)
    rate  = np.full(len(rxn), np.nan, dtype=float)
    valid = dt != 0
    rate[1:][valid] = dr[valid] / dt[valid]   # reactions / ns

    out = pd.DataFrame({"time_ns": time_ns, "rate": rate})
    if ROLL_POINTS and ROLL_POINTS > 1:
        out["rate_roll"] = out["rate"].rolling(
            ROLL_POINTS, center=True, min_periods=2
        ).mean()
    else:
        out["rate_roll"] = out["rate"]
    return out

def compute_top_rate(df_rxn, volume_L):
    """Polymer reactions / (NA * mean water volume) -> units: M/ns"""
    time_ns = df_rxn[STEP_COL].values.astype(float) * DT_FS * 1e-6
    out = _rolling_rate(df_rxn, time_ns)
    out["y"] = out["rate_roll"] / (NA * float(volume_L))
    return out

def compute_bottom_rate(df, V_L):
    """Water reactions / (NA * per-row water volume) -> units: M/ns"""
    time_ns = df[STEP_COL].values.astype(float) * DT_FS * 1e-6
    out = _rolling_rate(df, time_ns)
    V_L = np.asarray(V_L, dtype=float)
    if V_L.shape[0] != out.shape[0]:
        raise ValueError("V_L length does not match thermo rows.")
    out["y"] = out["rate_roll"] / (NA * V_L)
    return out

# =========================================================
# REPLICA AVERAGING ON COMMON TIME GRID
# =========================================================
def average_replicas(rep_list, n_interp=500):
    t_min  = max(r["time_ns"].dropna().iloc[0]  for r in rep_list)
    t_max  = min(r["time_ns"].dropna().iloc[-1] for r in rep_list)
    t_grid = np.linspace(t_min, t_max, n_interp)

    mat = []
    for r in rep_list:
        t    = r["time_ns"].values
        y    = r["y"].values
        mask = np.isfinite(y)
        mat.append(np.interp(t_grid, t[mask], y[mask]))

    arr  = np.vstack(mat)
    mean = np.nanmean(arr, axis=0)
    std  = np.nanstd(arr, axis=0, ddof=1) if arr.shape[0] > 1 else np.zeros_like(mean)
    return pd.DataFrame({"time_ns": t_grid, "mean": mean, "std": std})

# =========================================================
# BUILD + FILTER MATCHED FILES FOR TOP PANEL
# =========================================================
print("\n" + "=" * 100)
print("BUILDING MATCHED POLYMER / WATER REPLICA FILES FOR TOP PANEL")
print("=" * 100)

TOP_SYSTEM_FILES = {}   # poly_system -> list of dicts

for poly_system, water_conc in SYSTEM_MAP.items():

    raw_poly = sorted(glob(
        f"{POLYMER_BASE}/{poly_system}/Replica*/log.lammps"
    ))
    raw_water = sorted(glob(
        f"{WATER_BASE}/{water_conc}/Reacter_3.0/Replica*/log.lammps"
    ))

    print(f"\n{poly_system}  <->  {water_conc}")
    print(f"  Polymer replicas found : {len(raw_poly)}")
    print(f"  Water   replicas found : {len(raw_water)}")

    try:
        poly_paths  = filter_to_n_replicas(raw_poly,  REQUIRED_REPLICAS,
                                           f"{poly_system} polymer")
        water_paths = filter_to_n_replicas(raw_water, REQUIRED_REPLICAS,
                                           f"{water_conc} water")
    except ValueError as e:
        print(f"  SKIPPING — {e}")
        TOP_SYSTEM_FILES[poly_system] = []
        continue

    poly_map  = {extract_replica_number(p): p for p in poly_paths}
    water_map = {extract_replica_number(w): w for w in water_paths}
    common    = sorted(set(poly_map) & set(water_map))

    if len(common) < REQUIRED_REPLICAS:
        print(
            f"  SKIPPING — only {len(common)} replica number(s) matched "
            f"between polymer and water (need {REQUIRED_REPLICAS})."
        )
        TOP_SYSTEM_FILES[poly_system] = []
        continue

    matched = []
    for rep in common[:REQUIRED_REPLICAS]:
        matched.append({
            "replica":   rep,
            "poly_log":  poly_map[rep],
            "water_log": water_map[rep],
        })
        print(f"  Matched Replica{rep}")

    TOP_SYSTEM_FILES[poly_system] = matched

# =========================================================
# PROCESS TOP PANEL DATA
# =========================================================
print("\n" + "=" * 100)
print("PROCESSING TOP PANEL: POLYMER REACTION + WATER VOLUME")
print("=" * 100)

top_system_stats = {}   # poly_system -> averaged DataFrame

for poly_system in POLYMER_SYSTEMS:
    matched_files = TOP_SYSTEM_FILES.get(poly_system, [])
    if not matched_files:
        print(f"  SKIPPING {poly_system} — no matched files.")
        continue

    reps = []
    for item in matched_files:
        rep, poly_log, water_log = (
            item["replica"], item["poly_log"], item["water_log"]
        )
        try:
            df_rxn   = read_thermo_table(poly_log)
            volume_L = read_mean_volume_from_log(water_log)
            rep_df   = compute_top_rate(df_rxn, volume_L)
            reps.append(rep_df)
            print(
                f"  {poly_system} Replica{rep}: "
                f"mean water volume = {volume_L:.4e} L"
            )
        except Exception as e:
            print(f"  WARNING: Skipping {poly_system} Replica{rep}: {e}")

    if len(reps) == REQUIRED_REPLICAS:
        top_system_stats[poly_system] = average_replicas(reps)
        print(f"  -> Averaged {len(reps)} replicas for {poly_system}.")
    else:
        print(
            f"  SKIPPING {poly_system} — only {len(reps)} replica(s) "
            f"processed successfully (need {REQUIRED_REPLICAS})."
        )

# =========================================================
# BUILD + FILTER WATER FILES FOR BOTTOM PANEL
# =========================================================
print("\n" + "=" * 100)
print("BUILDING WATER FILES FOR BOTTOM PANEL")
print("=" * 100)

BOTTOM_SYSTEM_FILES = {}   # water_conc -> list of paths (exactly REQUIRED_REPLICAS)

for water_conc in WATER_SYSTEMS:
    raw = sorted(glob(
        f"{WATER_BASE}/{water_conc}/Reacter_3.0/Replica*/log.lammps"
    ))
    print(f"\n{water_conc}: {len(raw)} replica(s) found")

    try:
        paths = filter_to_n_replicas(raw, REQUIRED_REPLICAS, water_conc)
        BOTTOM_SYSTEM_FILES[water_conc] = paths
        for p in paths:
            print(f"  Accepted: {p}")
    except ValueError as e:
        print(f"  SKIPPING — {e}")
        BOTTOM_SYSTEM_FILES[water_conc] = []

# =========================================================
# PROCESS BOTTOM PANEL DATA
# =========================================================
print("\n" + "=" * 100)
print("PROCESSING BOTTOM PANEL: WATER REACTION + WATER VOLUME")
print("=" * 100)

bottom_system_stats = {}   # water_conc -> averaged DataFrame
volume_summary      = {}
reaction_summary    = {}

for water_conc, files in BOTTOM_SYSTEM_FILES.items():
    if not files:
        print(f"  SKIPPING {water_conc} — no files.")
        continue

    print(f"\n{'─'*80}")
    print(f"SYSTEM: {water_conc}  ({len(files)} replicas)")
    print(f"{'─'*80}")

    reps              = []
    replica_vols_ang3 = []
    replica_rxns      = []

    for fpath in files:
        try:
            df   = read_thermo_table(fpath)
            V_L  = volume_liters_array_from_log(fpath, df)
            rep  = compute_bottom_rate(df, V_L)
            reps.append(rep)

            final_rxn = float(df[RXN_COL].iloc[-1])
            replica_rxns.append(final_rxn)

            vmean_ang3 = float(np.nanmean(V_L / ANG3_TO_L))
            replica_vols_ang3.append(vmean_ang3)

            rname = os.path.basename(os.path.dirname(fpath))
            print(f"  {rname}")
            print(f"    File         : {fpath}")
            print(f"    Mean volume  : {vmean_ang3:.4f} Å³  "
                  f"({vmean_ang3 * ANG3_TO_L:.4e} L)")
            print(f"    Final rxns   : {final_rxn:.0f}")

        except Exception as e:
            print(f"  WARNING: Skipping {fpath}: {e}")

    if len(reps) == REQUIRED_REPLICAS:
        bottom_system_stats[water_conc] = average_replicas(reps)
        print(f"  -> Averaged {len(reps)} replicas for {water_conc}.")

        va = np.asarray(replica_vols_ang3, dtype=float)
        volume_summary[water_conc] = {
            "mean_ang3": float(np.nanmean(va)),
            "std_ang3":  float(np.nanstd(va, ddof=1)),
            "mean_L":    float(np.nanmean(va)) * ANG3_TO_L,
            "std_L":     float(np.nanstd(va, ddof=1)) * ANG3_TO_L,
        }
        ra = np.asarray(replica_rxns, dtype=float)
        reaction_summary[water_conc] = {
            "mean_rxn": float(np.nanmean(ra)),
            "std_rxn":  float(np.nanstd(ra, ddof=1)),
        }
    else:
        print(
            f"  SKIPPING {water_conc} — only {len(reps)} replica(s) "
            f"processed successfully (need {REQUIRED_REPLICAS})."
        )

# =========================================================
# PRINT + SAVE SUMMARY CSV
# =========================================================
print("\n" + "#" * 80)
print("VOLUME SUMMARY")
print("#" * 80)
for s in WATER_SYSTEMS:
    if s not in volume_summary:
        continue
    v = volume_summary[s]
    print(f"  {s}:  {v['mean_ang3']:.4f} ± {v['std_ang3']:.4f} Å³   "
          f"({v['mean_L']:.4e} ± {v['std_L']:.4e} L)")

print("\n" + "#" * 80)
print("REACTION SUMMARY")
print("#" * 80)
for s in WATER_SYSTEMS:
    if s not in reaction_summary:
        continue
    r = reaction_summary[s]
    print(f"  {s}:  {r['mean_rxn']:.0f} ± {r['std_rxn']:.0f} reactions")

rows = []
for s in WATER_SYSTEMS:
    if s not in volume_summary:
        continue
    v = volume_summary[s]
    r = reaction_summary.get(s, {"mean_rxn": np.nan, "std_rxn": np.nan})
    rows.append({
        "system":           DISPLAY_LABELS.get(s, s),
        "mean_volume_ang3": v["mean_ang3"],
        "std_volume_ang3":  v["std_ang3"],
        "mean_volume_L":    v["mean_L"],
        "std_volume_L":     v["std_L"],
        "mean_reactions":   r["mean_rxn"],
        "std_reactions":    r["std_rxn"],
    })

summary_df = pd.DataFrame(rows)
summary_df.to_csv(SUMMARY_CSV, index=False)
print(f"\nSaved: {SUMMARY_CSV}")
print(summary_df.to_string(index=False))

# =========================================================
# PLOT — stacked panels (a) top  (b) bottom
# =========================================================
fig, (ax1, ax2) = plt.subplots(
    2, 1,
    figsize=(10, 20),
    sharex=True,
    gridspec_kw={"hspace": 0.08},
)
ax1.set_box_aspect(1)
ax2.set_box_aspect(1)

# concentrations sorted low -> high for consistent legend order
sorted_concs = sorted(
    [s for s in WATER_SYSTEMS if s in bottom_system_stats],
    key=lambda c: float(c.replace("M", ""))
)

# ─────────────────────────────────────────
# TOP PANEL (a)  – polymer reaction rate
# Legend sorted ascending by concentration
# ─────────────────────────────────────────
handles_top, labels_top = [], []

for poly_system in sorted(
    POLYMER_SYSTEMS,
    key=lambda p: float(SYSTEM_MAP[p].replace("M", ""))
):
    if poly_system not in top_system_stats:
        continue

    water_conc = SYSTEM_MAP[poly_system]
    color      = CONC_COLORS.get(water_conc, "gray")
    df         = top_system_stats[poly_system]

    if XMAX_NS is not None:
        df = df[df["time_ns"] <= XMAX_NS]

    x, y, e = df["time_ns"].values, df["mean"].values, df["std"].values
    lbl = DISPLAY_LABELS.get(water_conc, water_conc)
    line, = ax1.plot(x, y, color=color, label=lbl)
    ax1.fill_between(x, y - e, y + e, color=color, alpha=BAND_ALPHA, linewidth=0)
    handles_top.append(line)
    labels_top.append(lbl)

ax1.set_ylabel("Reaction rate [M/ns]", fontsize=36, labelpad=25)
ax1.text(0.03, 0.92, "(a)", transform=ax1.transAxes,
         fontsize=36, fontweight="bold")
ax1.tick_params(labelbottom=False)

leg = ax1.legend(
    handles_top, labels_top,
    loc="center right",
    bbox_to_anchor=(0.98, 0.71),
    fontsize=20,
    frameon=False,
    handlelength=2.5,
)
for txt in leg.get_texts():
    txt.set_fontweight("bold")

# ─────────────────────────────────────────
# BOTTOM PANEL (b) – water reaction rate
# Legend sorted ascending by concentration
# ─────────────────────────────────────────
handles_bot, labels_bot = [], []

for water_conc in sorted_concs:
    color = CONC_COLORS.get(water_conc, "gray")
    df    = bottom_system_stats[water_conc]

    if XMAX_NS is not None:
        df = df[df["time_ns"] <= XMAX_NS]

    x, y, e = df["time_ns"].values, df["mean"].values, df["std"].values
    lbl = DISPLAY_LABELS.get(water_conc, water_conc)
    line, = ax2.plot(x, y, color=color, label=lbl)
    ax2.fill_between(x, y - e, y + e, color=color, alpha=BAND_ALPHA, linewidth=0)
    handles_bot.append(line)
    labels_bot.append(lbl)

ax2.set_xlabel("Time [ns]", fontsize=36, fontweight="bold")
ax2.set_ylabel("Reaction rate [M/ns]", fontsize=36, labelpad=25)
ax2.text(0.03, 0.92, "(b)", transform=ax2.transAxes,
         fontsize=36, fontweight="bold")
ax2.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=4))

# Uncomment below to show legend on bottom panel too
# leg2 = ax2.legend(handles_bot, labels_bot, loc="upper right",
#                   fontsize=20, frameon=False, handlelength=2.5)
# for txt in leg2.get_texts():
#     txt.set_fontweight("bold")

# ─────────────────────────────────────────
# SHARED AXIS STYLE
# ─────────────────────────────────────────
for ax in (ax1, ax2):
    for spine in ax.spines.values():
        spine.set_linewidth(5)
    ax.tick_params(direction="in", width=5, length=12)
    ax.minorticks_on()
    for lbl in ax.get_xticklabels() + ax.get_yticklabels():
        lbl.set_fontweight("bold")
        lbl.set_fontsize(34)

fig.tight_layout()
fig.savefig(f"{OUT_PREFIX}.png", dpi=600, bbox_inches="tight")
fig.savefig(f"{OUT_PREFIX}.pdf",              bbox_inches="tight")
plt.show()

print("\nSaved:", f"{OUT_PREFIX}.png")
print("Saved:", f"{OUT_PREFIX}.pdf")
# Out:
# ====================================================================================================
# BUILDING MATCHED POLYMER / WATER REPLICA FILES FOR TOP PANEL
# ====================================================================================================
#
# PE_A1  <->  0.257M
#   Polymer replicas found : 4
#   Water   replicas found : 3
#   [PE_A1 polymer] 4 replicas found — keeping first 3, dropping:
#     /blue/jsampath/avemula/Paper1_PE/Polymer/PE_A1/Replica4/log.lammps
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# PE_A2  <->  0.128M
#   Polymer replicas found : 3
#   Water   replicas found : 3
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# PE_P1  <->  0.578M
#   Polymer replicas found : 5
#   Water   replicas found : 3
#   [PE_P1 polymer] 5 replicas found — keeping first 3, dropping:
#     /blue/jsampath/avemula/Paper1_PE/Polymer/PE_P1/Replica4/log.lammps
#     /blue/jsampath/avemula/Paper1_PE/Polymer/PE_P1/Replica5/log.lammps
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# PE_P2  <->  0.210M
#   Polymer replicas found : 4
#   Water   replicas found : 3
#   [PE_P2 polymer] 4 replicas found — keeping first 3, dropping:
#     /blue/jsampath/avemula/Paper1_PE/Polymer/PE_P2/Replica4/log.lammps
#   Matched Replica1
#   Matched Replica2
#   Matched Replica3
#
# ====================================================================================================
# PROCESSING TOP PANEL: POLYMER REACTION + WATER VOLUME
# ====================================================================================================
#   PE_A1 Replica1: mean water volume = 1.5919e-22 L
#   PE_A1 Replica2: mean water volume = 1.5919e-22 L
#   PE_A1 Replica3: mean water volume = 1.5919e-22 L
#   -> Averaged 3 replicas for PE_A1.
#   PE_A2 Replica1: mean water volume = 3.1884e-22 L
#   PE_A2 Replica2: mean water volume = 3.1884e-22 L
#   PE_A2 Replica3: mean water volume = 3.1884e-22 L
#   -> Averaged 3 replicas for PE_A2.
#   PE_P1 Replica1: mean water volume = 8.7140e-23 L
#   PE_P1 Replica2: mean water volume = 8.7140e-23 L
#   PE_P1 Replica3: mean water volume = 8.7140e-23 L
#   -> Averaged 3 replicas for PE_P1.
#   PE_P2 Replica1: mean water volume = 2.1849e-22 L
#   PE_P2 Replica2: mean water volume = 2.1849e-22 L
#   PE_P2 Replica3: mean water volume = 2.1849e-22 L
#   -> Averaged 3 replicas for PE_P2.
#
# ====================================================================================================
# BUILDING WATER FILES FOR BOTTOM PANEL
# ====================================================================================================
#
# 0.257M: 3 replica(s) found
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.257M/Reacter_3.0/Replica1/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.257M/Reacter_3.0/Replica2/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.257M/Reacter_3.0/Replica3/log.lammps
#
# 0.128M: 3 replica(s) found
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.128M/Reacter_3.0/Replica1/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.128M/Reacter_3.0/Replica2/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.128M/Reacter_3.0/Replica3/log.lammps
#
# 0.578M: 3 replica(s) found
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.578M/Reacter_3.0/Replica1/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.578M/Reacter_3.0/Replica2/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.578M/Reacter_3.0/Replica3/log.lammps
#
# 0.210M: 3 replica(s) found
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.210M/Reacter_3.0/Replica1/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.210M/Reacter_3.0/Replica2/log.lammps
#   Accepted: /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.210M/Reacter_3.0/Replica3/log.lammps
#
# ====================================================================================================
# PROCESSING BOTTOM PANEL: WATER REACTION + WATER VOLUME
# ====================================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# SYSTEM: 0.257M  (3 replicas)
# ────────────────────────────────────────────────────────────────────────────────
#   Replica1
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.257M/Reacter_3.0/Replica1/log.lammps
#     Mean volume  : 159192.9995 Å³  (1.5919e-22 L)
#     Final rxns   : 21786
#   Replica2
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.257M/Reacter_3.0/Replica2/log.lammps
#     Mean volume  : 159192.9995 Å³  (1.5919e-22 L)
#     Final rxns   : 21964
#   Replica3
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.257M/Reacter_3.0/Replica3/log.lammps
#     Mean volume  : 159192.9995 Å³  (1.5919e-22 L)
#     Final rxns   : 22364
#   -> Averaged 3 replicas for 0.257M.
#
# ────────────────────────────────────────────────────────────────────────────────
# SYSTEM: 0.128M  (3 replicas)
# ────────────────────────────────────────────────────────────────────────────────
#   Replica1
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.128M/Reacter_3.0/Replica1/log.lammps
#     Mean volume  : 318844.8044 Å³  (3.1884e-22 L)
#     Final rxns   : 93503
#   Replica2
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.128M/Reacter_3.0/Replica2/log.lammps
#     Mean volume  : 318844.8044 Å³  (3.1884e-22 L)
#     Final rxns   : 95190
#   Replica3
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.128M/Reacter_3.0/Replica3/log.lammps
#     Mean volume  : 318844.8044 Å³  (3.1884e-22 L)
#     Final rxns   : 93489
#   -> Averaged 3 replicas for 0.128M.
#
# ────────────────────────────────────────────────────────────────────────────────
# SYSTEM: 0.578M  (3 replicas)
# ────────────────────────────────────────────────────────────────────────────────
#   Replica1
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.578M/Reacter_3.0/Replica1/log.lammps
#     Mean volume  : 87140.0144 Å³  (8.7140e-23 L)
#     Final rxns   : 63359
#   Replica2
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.578M/Reacter_3.0/Replica2/log.lammps
#     Mean volume  : 87140.0144 Å³  (8.7140e-23 L)
#     Final rxns   : 63459
#   Replica3
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.578M/Reacter_3.0/Replica3/log.lammps
#     Mean volume  : 87140.0144 Å³  (8.7140e-23 L)
#     Final rxns   : 62941
#   -> Averaged 3 replicas for 0.578M.
#
# ────────────────────────────────────────────────────────────────────────────────
# SYSTEM: 0.210M  (3 replicas)
# ────────────────────────────────────────────────────────────────────────────────
#   Replica1
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.210M/Reacter_3.0/Replica1/log.lammps
#     Mean volume  : 218485.8454 Å³  (2.1849e-22 L)
#     Final rxns   : 137057
#   Replica2
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.210M/Reacter_3.0/Replica2/log.lammps
#     Mean volume  : 218485.8454 Å³  (2.1849e-22 L)
#     Final rxns   : 136154
#   Replica3
#     File         : /blue/jsampath/avemula/Paper1_PE/Water/TMA_OH_water/0.210M/Reacter_3.0/Replica3/log.lammps
#     Mean volume  : 218485.8454 Å³  (2.1849e-22 L)
#     Final rxns   : 138854
#   -> Averaged 3 replicas for 0.210M.
#
# ################################################################################
# VOLUME SUMMARY
# ################################################################################
#   0.257M:  159192.9995 ± 0.0000 Å³   (1.5919e-22 ± 0.0000e+00 L)
#   0.128M:  318844.8044 ± 0.0000 Å³   (3.1884e-22 ± 0.0000e+00 L)
#   0.578M:  87140.0144 ± 0.0000 Å³   (8.7140e-23 ± 0.0000e+00 L)
#   0.210M:  218485.8454 ± 0.0000 Å³   (2.1849e-22 ± 0.0000e+00 L)
#
# ################################################################################
# REACTION SUMMARY
# ################################################################################
#   0.257M:  22038 ± 296 reactions
#   0.128M:  94061 ± 978 reactions
#   0.578M:  63253 ± 275 reactions
#   0.210M:  137355 ± 1374 reactions
#
# Saved: water_system_volume_reaction_summary.csv
#  system  mean_volume_ang3  std_volume_ang3  mean_volume_L  std_volume_L  mean_reactions  std_reactions
# 0.257 M     159192.999502              0.0   1.591930e-22           0.0    22038.000000     296.020270
# 0.128 M     318844.804436              0.0   3.188448e-22           0.0    94060.666667     978.056406
# 0.578 M      87140.014442              0.0   8.714001e-23           0.0    63253.000000     274.787190
# 0.210 M     218485.845447              0.0   2.184858e-22           0.0   137355.000000    1374.446434
# /scratch/local/31278334/ipykernel_307264/4087866619.py:702: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Saved: PE_rate_compare_stacked_ACS_panels.png
# Saved: PE_rate_compare_stacked_ACS_panels.pdf
